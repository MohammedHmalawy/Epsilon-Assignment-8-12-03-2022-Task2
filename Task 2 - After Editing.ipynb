# %%
import requests
import csv

# %%
response = requests.get("https://www.metaweather.com/api/location/1521894/")

# %%
response
# Out:
# <Response [200]>

# %%
Weather = response.json()
Weather
# Out:
# {'consolidated_weather': [{'id': 4647921845796864,
#    'weather_state_name': 'Heavy Cloud',
#    'weather_state_abbr': 'hc',
#    'wind_direction_compass': 'N',
#    'created': '2022-03-12T13:34:22.291697Z',
#    'applicable_date': '2022-03-12',
#    'min_temp': 8.08,
#    'max_temp': 17.97,
#    'the_temp': 15.39,
#    'wind_speed': 7.951509927635939,
#    'wind_direction': 355.8790376274046,
#    'air_pressure': 1016.5,
#    'humidity': 40,
#    'visibility': 9.919880398472918,
#    'predictability': 71},
#   {'id': 5658393332154368,
#    'weather_state_name': 'Light Cloud',
#    'weather_state_abbr': 'lc',
#    'wind_direction_compass': 'NNW',
#    'created': '2022-03-12T13:34:25.444713Z',
#    'applicable_date': '2022-03-13',
#    'min_temp': 7.109999999999999,
#    'max_temp': 17.494999999999997,
#    'the_temp': 16.564999999999998,
#    'wind_speed': 7.891282822614596,
#    'wind_direction': 345.25978015932293,
#    'air_pressure': 1021.5,
#    'humidity': 40,
#    'visibility': 12.370879066253082,
#    'predictability': 70},
#   {'id': 5314157172752384,
#    'weather_state_name': 'Light Cloud',
#    'weather_state_abbr': 'lc',
#    'wind_direction_compass': 'NNW',
#    'created': '2022-03-12T13:34:28.274544Z',
#    'applicable_date': '2022-03-14',
#    'min_temp': 5.99,
#    'max_temp': 17.625,
#    'the_temp': 15.145,
#    'wind_speed': 9.055094479145788,
#    'wind_direction': 336.8364053906784,
#    'air_pressure': 1025.0,
#    'humidity': 38,
#    'visibility': 11.006347928099895,
#    'predictability': 70},
#   {'id': 5672890692272128,
#    'weather_state_name': 'Heavy Cloud',
#    'weather_state_abbr': 'hc',
#    'wind_direction_compass': 'NNW',
#    'created': '2022-03-12T13:34:31.252498Z',
#    'applicable_date': '2022-03-15',
#    'min_temp': 7.775,
#    'max_temp': 16.875,
#    'the_temp': 16.225,
#    'wind_speed': 10.803990249479043,
#    'wind_direction': 338.4998095452205,
#    'air_pressure': 1025.0,
#    'humidity': 35,
#    'visibility': 11.01007615525332,
#    'predictability': 71},
#   {'id': 6271162456735744,
#    'weather_state_name': 'Clear',
#    'weather_state_abbr': 'c',
#    'wind_direction_compass': 'N',
#    'created': '2022-03-12T13:34:34.280810Z',
#    'applicable_date': '2022-03-16',
#    'min_temp': 7.535,
#    'max_temp': 19.735,
#    'the_temp': 17.555,
#    'wind_speed': 6.853129135491398,
#    'wind_direction': 349.18459724655975,
#    'air_pressure': 1026.0,
#    'humidity': 34,
#    'visibility': 12.724128589040006,
#    'predictability': 68},
#   {'id': 6655225143230464,
#    'weather_state_name': 'Clear',
#    'weather_state_abbr': 'c',
#    'wind_direction_compass': 'NNE',
#    'created': '2022-03-12T13:34:37.344183Z',
#    'applicable_date': '2022-03-17',
#    'min_temp': 7.655,
#    'max_temp': 22.725,
#    'the_temp': 15.8,
#    'wind_speed': 3.2730851825340013,
#    'wind_direction': 26.0,
#    'air_pressure': 1025.0,
#    'humidity': 37,
#    'visibility': 9.999726596675416,
#    'predictability': 68}],
#  'time': '2022-03-12T18:12:32.136441+02:00',
#  'sun_rise': '2022-03-12T06:08:43.480492+02:00',
#  'sun_set': '2022-03-12T18:01:15.557974+02:00',
#  'timezone_name': 'LMT',
#  'parent': {'title': 'Egypt',
#   'location_type': 'Country',
#   'woeid': 23424802,
#   'latt_long': '26.837090,30.796391'},
#  'sources': [{'title': 'BBC',
#    'slug': 'bbc',
#    'url': 'http://www.bbc.co.uk/weather/',
#    'crawl_rate': 360},
#   {'title': 'Forecast.io',
#    'slug': 'forecast-io',
#    'url': 'http://forecast.io/',
#    'crawl_rate': 480},
#   {'title': 'HAMweather',
#    'slug': 'hamweather',
#    'url': 'http://www.hamweather.com/',
#    'crawl_rate': 360},
#   {'title': 'Met Office',
#    'slug': 'met-office',
#    'url': 'http://www.metoffice.gov.uk/',
#    'crawl_rate': 180},
#   {'title': 'OpenWeatherMap',
#    'slug': 'openweathermap',
#    'url': 'http://openweathermap.org/',
#    'crawl_rate': 360},
#   {'title': 'Weather Underground',
#    'slug': 'wunderground',
#    'url': 'https://www.wunderground.com/?apiref=fc30dc3cd224e19b',
#    'crawl_rate': 720},
#   {'title': 'World Weather Online',
#    'slug': 'world-weather-online',
#    'url': 'http://www.worldweatheronline.com/',
#    'crawl_rate': 360}],
#  'title': 'Cairo',
#  'location_type': 'City',
#  'woeid': 1521894,
#  'latt_long': '30.049950,31.248600',
#  'timezone': 'Africa/Cairo'}

# %%
Weather['consolidated_weather']
# Out:
# [{'id': 4647921845796864,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'N',
#   'created': '2022-03-12T13:34:22.291697Z',
#   'applicable_date': '2022-03-12',
#   'min_temp': 8.08,
#   'max_temp': 17.97,
#   'the_temp': 15.39,
#   'wind_speed': 7.951509927635939,
#   'wind_direction': 355.8790376274046,
#   'air_pressure': 1016.5,
#   'humidity': 40,
#   'visibility': 9.919880398472918,
#   'predictability': 71},
#  {'id': 5658393332154368,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NNW',
#   'created': '2022-03-12T13:34:25.444713Z',
#   'applicable_date': '2022-03-13',
#   'min_temp': 7.109999999999999,
#   'max_temp': 17.494999999999997,
#   'the_temp': 16.564999999999998,
#   'wind_speed': 7.891282822614596,
#   'wind_direction': 345.25978015932293,
#   'air_pressure': 1021.5,
#   'humidity': 40,
#   'visibility': 12.370879066253082,
#   'predictability': 70},
#  {'id': 5314157172752384,
#   'weather_state_name': 'Light Cloud',
#   'weather_state_abbr': 'lc',
#   'wind_direction_compass': 'NNW',
#   'created': '2022-03-12T13:34:28.274544Z',
#   'applicable_date': '2022-03-14',
#   'min_temp': 5.99,
#   'max_temp': 17.625,
#   'the_temp': 15.145,
#   'wind_speed': 9.055094479145788,
#   'wind_direction': 336.8364053906784,
#   'air_pressure': 1025.0,
#   'humidity': 38,
#   'visibility': 11.006347928099895,
#   'predictability': 70},
#  {'id': 5672890692272128,
#   'weather_state_name': 'Heavy Cloud',
#   'weather_state_abbr': 'hc',
#   'wind_direction_compass': 'NNW',
#   'created': '2022-03-12T13:34:31.252498Z',
#   'applicable_date': '2022-03-15',
#   'min_temp': 7.775,
#   'max_temp': 16.875,
#   'the_temp': 16.225,
#   'wind_speed': 10.803990249479043,
#   'wind_direction': 338.4998095452205,
#   'air_pressure': 1025.0,
#   'humidity': 35,
#   'visibility': 11.01007615525332,
#   'predictability': 71},
#  {'id': 6271162456735744,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'N',
#   'created': '2022-03-12T13:34:34.280810Z',
#   'applicable_date': '2022-03-16',
#   'min_temp': 7.535,
#   'max_temp': 19.735,
#   'the_temp': 17.555,
#   'wind_speed': 6.853129135491398,
#   'wind_direction': 349.18459724655975,
#   'air_pressure': 1026.0,
#   'humidity': 34,
#   'visibility': 12.724128589040006,
#   'predictability': 68},
#  {'id': 6655225143230464,
#   'weather_state_name': 'Clear',
#   'weather_state_abbr': 'c',
#   'wind_direction_compass': 'NNE',
#   'created': '2022-03-12T13:34:37.344183Z',
#   'applicable_date': '2022-03-17',
#   'min_temp': 7.655,
#   'max_temp': 22.725,
#   'the_temp': 15.8,
#   'wind_speed': 3.2730851825340013,
#   'wind_direction': 26.0,
#   'air_pressure': 1025.0,
#   'humidity': 37,
#   'visibility': 9.999726596675416,
#   'predictability': 68}]

# %%
for w in Weather['consolidated_weather'][0:3]:
    print(w['the_temp'],'|',w['humidity'],'|',w['visibility'],'|',w['air_pressure'],'|',w['wind_speed'],'|',w['created'])
# Out:
# 15.39 | 40 | 9.919880398472918 | 1016.5 | 7.951509927635939 | 2022-03-12T13:34:22.291697Z
# 16.564999999999998 | 40 | 12.370879066253082 | 1021.5 | 7.891282822614596 | 2022-03-12T13:34:25.444713Z
# 15.145 | 38 | 11.006347928099895 | 1025.0 | 9.055094479145788 | 2022-03-12T13:34:28.274544Z

# %%
with open ('Weather.csv', 'w', newline='') as f:
    writer = csv.DictWriter(f, fieldnames=['Weather Temperature','Humidity','Visibility','Air Pressure','Wind Speed','Datetime'])
    writer.writeheader()
    
    for w in Weather['consolidated_weather'][0:3]:
        Weather_Temperature = w['the_temp']
        Humidity = w['humidity']
        Visibility = w['visibility']
        Air_Pressure = w['air_pressure']
        Wind_Speed = w['wind_speed']
        Datetime = w['created']
        
        writer.writerow(
            {
                'Weather Temperature' : Weather_Temperature,
                'Humidity' : Humidity,
                'Visibility' : Visibility,
                'Air Pressure' : Air_Pressure,
                'Wind Speed' : Wind_Speed,
                'Datetime' : Datetime
            }
        )

# %%
import pandas as pd

Weather_Table = pd.read_csv('Weather.csv')
Weather_Table
# Out:
#    Weather Temperature  Humidity  Visibility  Air Pressure  Wind Speed  \
# 0               15.390        40    9.919880        1016.5    7.951510
# 1               16.565        40   12.370879        1021.5    7.891283
# 2               15.145        38   11.006348        1025.0    9.055094
#
#                       Datetime
# 0  2022-03-12T13:34:22.291697Z
# 1  2022-03-12T13:34:25.444713Z
# 2  2022-03-12T13:34:28.274544Z
